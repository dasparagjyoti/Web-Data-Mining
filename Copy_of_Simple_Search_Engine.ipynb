# %% [markdown]
# <a href="https://colab.research.google.com/github/dasparagjyoti/Web-Data-Mining/blob/main/Copy_of_Simple_Search_Engine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Create A Simple Search Engine Using Python
# ## Utilize TF-IDF and Cosine Similarity to retrieve similar articles with query
# [EN] Information Retrieval right now is an important task. Probably you're wondering, how does the system can retrieve articles that we want using a query? Here are the steps,
# 1. Extract documents from the Internet (It could be Web Scraping or extract manually)
# 2. Clean the documents to make the retrieval much easier
# 3. Create a Term-Document Matrix with TF-IDF weighting
# 4. Write your queries and convert it as vector (based on TF-IDF)
# 5. Calculate the cosine similarity between the query and the document and repeat the process on each document.
# 6. Finally, show the document
# ---------
# # Membuat Search Engine Sederhana dengan TF-IDF dan Cosine Similarity
# [ID] Menemukan informasi merupakan suatu hal yang penting mengingat jumlah informasi yang semakin banyak. Namun, bagaimana caranya untuk menemukan suatu dokumen berdasarkan query yang kita inginkan? Berikut tahapannya,
# 1. Ekstrak Dokumen dari Internet (Bisa Menggunakan Web Scraping atau manual)
# 2. Bersihkan isi dokumen tersebut agar memudahkan proses analisis
# 3. Buatlah Term-Document Matrix dengan pembobotan TF-IDF
# 4. Tuliskanlah query yang diinginkan dan ubahlah ke dalam bentuk vector (sesuai dengan matriks TF-IDF)
# 5. Lakukan pengulangan antar dokumen untuk menghitung similaritas kosinus dengan query yang digunakan dan tampilkan dokumen dengan similaritas > 0
# 6. Finally, show the document
#
# ### Created by Irfan Alghani Khalid

# %%
import re
import string
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import TfidfVectorizer

def retrieve_docs_and_clean():
  # Untuk mendapatkan link berita populer
  r = requests.get('https://www.w3schools.com/')
  soup = BeautifulSoup(r.content, 'html.parser')

  link = []
  for i in soup.find('div', {'class':'most__wrap'}).find_all('a'):
      i['href'] = i['href'] + '?page=all'
      link.append(i['href'])

  # Retrieve Paragraphs
  documents = []
  for i in link:
      r = requests.get(i)
      soup = BeautifulSoup(r.content, 'html.parser')

      sen = []
      for i in soup.find('div', {'class':'read__content'}).find_all('p'):
          sen.append(i.text)
      documents.append(' '.join(sen))

  # Clean Paragraphs
  documents_clean = []
  for d in documents:
      document_test = re.sub(r'[^\x00-\x7F]+', ' ', d)
      document_test = re.sub(r'@\w+', '', document_test)
      document_test = document_test.lower()
      document_test = re.sub(r'[%s]' % re.escape(string.punctuation), ' ', document_test)
      document_test = re.sub(r'[0-9]', '', document_test)
      document_test = re.sub(r'\s{2,}', ' ', document_test)
      documents_clean.append(document_test)

  return documents_clean

# %%
docs = retrieve_docs_and_clean()

# Create Term-Document Matrix with TF-IDF weighting
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(docs)

# Create a DataFrame
df = pd.DataFrame(X.T.toarray(), index=vectorizer.get_feature_names())
print(df.head())
print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-4895aa20b4b8> in <module>()
# ----> 1 docs = retrieve_docs_and_clean()
#       2
#       3 # Create Term-Document Matrix with TF-IDF weighting
#       4 vectorizer = TfidfVectorizer()
#       5 X = vectorizer.fit_transform(docs)
#
# <ipython-input-1-f86e28654d5e> in retrieve_docs_and_clean()
#      13
#      14   link = []
# ---> 15   for i in soup.find('div', {'class':'most__wrap'}).find_all('a'):
#      16       i['href'] = i['href'] + '?page=all'
#      17       link.append(i['href'])
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
docs = retrieve_docs_and_clean()
# Create Term-Document Matrix with TF-IDF weighting
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(docs)

# Create a DataFrame
df = pd.DataFrame(X.T.toarray(), index=vectorizer.get_feature_names())
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#                0         1         2         3         4         5         6  \
# absen   0.000000  0.000000  0.000000  0.000000  0.000000  0.035829  0.000000
# ac      0.000000  0.000000  0.000000  0.031057  0.000000  0.000000  0.000000
# acara   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.016402
# ada     0.046920  0.045287  0.000000  0.000000  0.000000  0.027869  0.021691
# adalah  0.038093  0.012256  0.027732  0.000000  0.017182  0.000000  0.079246
#
#                7    8         9
# absen   0.000000  0.0  0.066786
# ac      0.000000  0.0  0.000000
# acara   0.000000  0.0  0.000000
# ada     0.000000  0.0  0.000000
# adalah  0.016004  0.0  0.000000

# %%
def get_similar_articles(q, df):
  print("query:", q)
  print("The following is the article with the highest cosine similarity value:")
  q = [q]
  q_vec = vectorizer.transform(q).toarray().reshape(df.shape[0],)
  sim = {}
  for i in range(10):
    sim[i] = np.dot(df.loc[:, i].values, q_vec) / np.linalg.norm(df.loc[:, i]) * np.linalg.norm(q_vec)
  
  sim_sorted = sorted(sim.items(), key=lambda x: x[1], reverse=True)
  
  for k, v in sim_sorted:
    if v != 0.0:
      print("Similarity Value:", v)
      print(docs[k])
      print()


q1 = 'barcelona'
q2 = 'gareth bale'
q3 = 'shin tae yong'

get_similar_articles(q1, df)
print('-'*100)
get_similar_articles(q2, df)
print('-'*100)
get_similar_articles(q3, df)
# Out:
# query: barcelona
# The following is the article with the highest cosine similarity value:
# ----------------------------------------------------------------------------------------------------
# query: gareth bale
# The following is the article with the highest cosine similarity value:
# ----------------------------------------------------------------------------------------------------
# query: shin tae yong
# The following is the article with the highest cosine similarity value:
# Similarity Value: 0.030445917836089895
# kompas com ganda putra indonesia fajar alfian muhammad rian ardianto membuka perjuangan di korea open dengan kemenangan fajar rian bertanding dengan gwang min na jon seong noh pada babak pertama atau besar korea open selasa pagi wib baca juga jadwal korea open wakil indonesia beraksi di besar hari ini bertanding di palma stadium suncheon fajar rian mulus ke babak selanjutnya setelah menang dua gim atas gwang jon ganda putra nomor dunia itu berhasil menang dengan dalam tempo menit selanjutnya fajar rian akan menghadapi pemenang antara hwi tae kim dae il yoon korsel dan tan kian meng tan wee kiong malaysia pada babak besar jalannya pertandingan fajar rian merupakan juara bertahan korea open di sektor ganda putra mereka menjadi juara pada edisi dua tahun berselang korea open dibatalkan karena pandemi covid sehingga fajar rian masih berstatus sebagai juara bertahan fajar rian memulai laga dengan cukup baik dan langsung bisa mengatasi pola permainan lawan meski mendapatkan perlawanan cukup sengit dari gwang jin fajar rian yang berstatus sebagai unggulan keempat ini mampu melewati interval dengan keunggulan konsistensi fajar rian terus berlanjut usai jeda dengan pukulan pukulan efektif yang dilancarkan baca juga kondisi wakil indonesia jelang korea open belum persen tapi siap tempur sempat beberapa kali melewati reli fajar rian mampu menjaga keunggulan dan tak membiarkan lawan memangkas skor kurang dari tiga poin pada akhirnya poin demi poin terus dicetak fajar rian dan mereka menutup gim pertama dengan kemenangan fajar rian semakin agresif pada gim kedua pasangan indonesia mencetak lima poin beruntun dengan cepat dan unggul baca juga hasil drawing ulang korea open dua ganda campuran indonesia langsung lolos ke besar gwang jin yang banyak menunjukkan kelengahan tak mampu berbuah banyal fajar rian menutup interval dengan keunggulan wakil tuan rumah mulai merespons lebih baik selepas interval namun konsistensi fajar alfian mampu membuat mereka terus unggul dan mencapai skor sempat kecolongan lagi fajar rian akhirnya dapat menuntaskan perlawanan gwang jin dengan skor
#
# Similarity Value: 0.02508785894610103
# kompas com sebanyak enam wakil indonesia berlaga pada hari pertama babak besar korea open tunggal putra anthony sinisuka ginting langsung gugur sementara dua ganda putra menciptakan duel merah putih di besar korea open yang merupakan turnamen bulu tangkis kategori bwf world tour super mulai digelar hari ini selasa di palma stadium suncheon korea selatan indonesia sendiri mengirim wakilnya ke turnamen korea open edisi ini pada hari pertama babak besar ada enam wakil merah putih yang berlaga di nomor ganda putra wakil indonesia yang bertanding hari ini adalah fajar alfian muhammad rian ardianto muhammad shohibul fikri bagas maulana pramudya kusumawardana yeremia erich yoche yacob rambitan dan leo rolly carnando daniel marthin sementara di sektor tunggal putra ada anthony sinisuka ginting dan juga shesar hiren rhustavito baca juga kondisi wakil indonesia jelang korea open belum persen tapi siap tempur muhammad shohibul fikri bagas maulana yang baru saja meraih gelar juara all england langsung melaju ke besar setelah lawannya yakni ko sung hyun shin baek cheol asal korea selatan dinyatakan walkover alias wo ganda putra indonesia lainnya yaitu fajar alfian muhammad rian ardianto juga sukses menggenggam tiket ke besar usai menang atas wakil tuan rumah gwang min na jin seong noh dengan skor dan pramudya kusumawardana yeremia rambitan lantas menyusul dua rekannya itu ke besar setelah melewati adangan ganda putra india krishna prasad garaga vishnuvardhan goud panjala bertanding dua gim pramudya yeremia mampu menekuk garaga panjala dengan skor dan pada babak besar pramudya yeremia akan melawan fikri bagas dalam duel merah putih di korea open baca juga hasil korea open bungkam wakil jepang leo daniel lolos ke babak besar leo rolly carnando daniel marthin lantas melengkapi hasil manis ganda putra indonesia pada hari pertama babak besar korea open menghadapi wakil jepang hiroki okamura masayuki onodera leo daniel harus bermain rubber game sebelum mengamankan kemenangan dengan skor dan pramudya yeremia ke besar untuk hadapi bagas fikri badmintonindonesia koreaopen pic twitter com trlfvpver hasil kurang bagus diraih oleh tunggal putra nomor indonesia anthony sinisuka ginting melawan pemain non unggulan asal perancis lucas claerbout ginting takluk dua gim langsung lucas claerbout berhasil mengalahkan anthony ginting yang juga menjadi unggulan pertama korea open dengan skor dan hasil berbeda diraih oleh tunggal putra merah putih lainnya shesar hiren rhustavito baca juga korea open fajar rian masih adaptasi meski menang mudah vito sapaan akrab shesar hiren sukses melangkah ke besar korea open usai mengalahkan tunggal putra thailand sitthikom thammasin vito harus berjuang hingga gim ketiga untuk menaklukkan sitthikom dan berikut adalah rekap hasil korea open untuk wakil indonesia pada hari pertama babak besar ganda putra md tunggal putra ms
